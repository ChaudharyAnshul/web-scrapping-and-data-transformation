# %%
# !pip install diagrams
# Out:
# Collecting diagrams
#   Downloading diagrams-0.23.4-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: graphviz<0.21.0,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diagrams) (0.20.3)
# Requirement already satisfied: jinja2<4.0,>=2.10 in /usr/local/lib/python3.10/dist-packages (from diagrams) (3.1.4)
# Collecting typed-ast<2.0.0,>=1.5.4 (from diagrams)
#   Downloading typed_ast-1.5.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0,>=2.10->diagrams) (2.1.5)
# Downloading diagrams-0.23.4-py3-none-any.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 22.2 MB/s eta 0:00:00
# Downloading typed_ast-1.5.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (824 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.7/824.7 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: typed-ast, diagrams
# Successfully installed diagrams-0.23.4 typed-ast-1.5.5

# %%
from diagrams import Diagram, Cluster, Edge
from diagrams.aws.storage import SimpleStorageServiceS3
from diagrams import Cluster, Diagram
from diagrams.programming.language import Python
from urllib.request import urlretrieve
from diagrams.custom import Custom
from diagrams.digitalocean.storage import Folder
from diagrams.oci.connectivity import DNS
from diagrams.elastic.beats import Filebeat
from diagrams.generic.database import SQL

# %%
graph_attr = {
  "width": "1000",
  "height": "1000"
}

with Diagram("\n\nArchitecture Diagram \n\n\nWorkflow : Structured Data and Text Extraction \nSystem for Finance Professional", show=False, graph_attr=graph_attr, direction="LR") as diag:

  cfa_website = DNS("CFA Websites")

  pdf_file = Filebeat("PDF Files")

  with Cluster("\nScrapping"):
    py_web_scrapping = Python("\nExtract\nCFA Data")
    py_pdf_extraction = Python("\nExtract\nPDF Text")

  with Cluster("\Data Cleaning"):
    py_cleaner = Python("\nData Cleaner")
    py_validator = Python("\nData validator")

  py_upload_pdf = Python("\nUpload Clean\nPDF Text")

  py_upload_data = Python("\nUpload Clean\nStructured Data")

  snowflake_db_url = "https://pbs.twimg.com/media/EDT-rsuWwAAmhav.png"
  snowflake_db_icon = "elastic.png"
  urlretrieve(snowflake_db_url, snowflake_db_icon)
  snowflake_db = Custom("Snowflake\nData Warehouse", snowflake_db_icon, edge_label=" ", x_pos="1", y_pos="1")

  s3_bucket = SimpleStorageServiceS3("\nS3 Bucket")

  with Cluster("\nLocal Storage"):
    local_storage = Folder("\nTemporary\nStorage")

  with Cluster("\DBT transformation"):
    sql_1 = SQL("\n Transform Data")
    sql_2 = SQL("\n Deploy")

  cfa_website \
    >> py_web_scrapping \
    >> local_storage

  pdf_file \
    >> py_pdf_extraction \
    >> local_storage

  local_storage \
    >> py_cleaner \
    >> py_validator \

  py_validator >> py_upload_pdf
  py_validator >> py_upload_data

  py_upload_data \
    >> snowflake_db

  py_upload_pdf \
    >> s3_bucket

  snowflake_db >> sql_1 >> sql_2 >> snowflake_db

diag
# Out:
# Warning: node 'f9bda121f73541a59c1f22f4a6baa0eb', graph '
#
# Architecture Diagram
#
#
# Workflow : Structured Data and Text Extraction
# System for Finance Professional' size too small for label
# Warning: node 'dc5f985f69c345fdb1757ca1dc81653b', graph '
#
# Architecture Diagram
#
#
# Workflow : Structured Data and Text Extraction
# System for Finance Professional' size too small for label
# Warning: node '4488926acc0248b7abff484eeec0fe35', graph '
#
# Architecture Diagram
#
#
# Workflow : Structured Data and Text Extraction
# System for Finance Professional' size too small for label
# Warning: node 'bd85b072fc0647b9acec28658cb2c30f', graph '
#
# Architecture Diagram
#
#
# Workflow : Structured Data and Text Extraction
# System for Finance Professional' size too small for label
